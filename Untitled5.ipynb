# %% [markdown]
# <a href="https://colab.research.google.com/github/TahirRaheem/-Construction-Schedule-Planner/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly pandas

# %%
import pandas as pd
import plotly.express as px
from datetime import timedelta

# Function to create Gantt chart
def create_gantt_chart(df):
    fig = px.timeline(df, x_start="Start Date", x_end="End Date", y="Task",
                      color="Task", title="Construction Schedule Planner",
                      labels={"Task": "Construction Activities"})
    fig.update_yaxes(categoryorder="total ascending")  # Sort tasks
    fig.update_layout(xaxis_title="Timeline", yaxis_title="Task")
    fig.show()

# Input: Number of tasks
num_tasks = int(input("Enter the number of tasks: "))

tasks = []
start_dates = []
end_dates = []

# Loop to gather task details
for i in range(num_tasks):
    print(f"\nEnter details for Task {i+1}:")
    task_name = input(f"Task Name {i+1}: ")
    start_date = pd.to_datetime(input(f"Start Date {i+1} (YYYY-MM-DD): "))
    duration = int(input(f"Duration (days) for Task {i+1}: "))
    end_date = start_date + timedelta(days=duration)

    tasks.append(task_name)
    start_dates.append(start_date)
    end_dates.append(end_date)

# Create a DataFrame with the inputted tasks and dates
data = {
    "Task": tasks,
    "Start Date": start_dates,
    "End Date": end_dates
}
df = pd.DataFrame(data)

# Display Gantt chart
print("\nGantt Chart:")
create_gantt_chart(df)

# Display task data in table format
print("\nTask Schedule Data:")
df
# Out:
# Enter the number of tasks: 10
#
# Enter details for Task 1:
# Task Name 1: excavation
# Start Date 1 (YYYY-MM-DD): 24-10-20
# Duration (days) for Task 1: 10
#
# Enter details for Task 2:
# Task Name 2: PPC Work
# Start Date 2 (YYYY-MM-DD): 24-10-30
# Duration (days) for Task 2: 2
#
# Enter details for Task 3:
# Task Name 3: Footing Concrete
# Start Date 3 (YYYY-MM-DD): 24-11-01
# Duration (days) for Task 3: 5
#
# Enter details for Task 4:
# Task Name 4: steel quantity in footing
# Start Date 4 (YYYY-MM-DD): 24-11-06
# Duration (days) for Task 4: 5
#
# Enter details for Task 5:
# Task Name 5: DPC Work
# Start Date 5 (YYYY-MM-DD): 24-11-12
# Duration (days) for Task 5: 2
#
# Enter details for Task 6:
# Task Name 6: Plinth Beam Concrete
# Start Date 6 (YYYY-MM-DD): 24-11-14
# Duration (days) for Task 6: 5
#
# Enter details for Task 7:
# Task Name 7: Brick work in superstructure
# Start Date 7 (YYYY-MM-DD): 24-11-20
# Duration (days) for Task 7: 10
#
# Enter details for Task 8:
# ...
